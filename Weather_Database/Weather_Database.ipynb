# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_descrip = city_weather["weather"][0]["description"]     
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nemuro
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | enshi
# Processing Record 5 of Set 1 | puerto del rosario
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | khilok
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | koumac
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | carutapera
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | ankazoabo
# Processing Record 19 of Set 1 | finnsnes
# Processing Record 20 of Set 1 | nanortalik
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | ukiah
# Processing Record 23 of Set 1 | lebork
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | portland
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | meridian
# Processing Record 31 of Set 1 | lasa
# Processing Record 32 of Set 1 | port macquarie
# Processing Record 33 of Set 1 | adrar
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | sao filipe
# Processing Record 38 of Set 1 | lata
# Processing Record 39 of Set 1 | celles
# Processing Record 40 of Set 1 | quatre cocos
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | salamiyah
# Processing Record 43 of Set 1 | alice springs
# Processing Record 44 of Set 1 | burnie
# Processing Record 45 of Set 1 | agadez
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | faanui
# Processing Record 48 of Set 1 | warmbad
# Processing Record 49 of Set 1 | wasilla
# Processing Record 50 of Set 1 | coquimbo
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | ullapool
# Processing Record 3 of Set 2 | alamogordo
# Processing Record 4 of Set 2 | fleurus
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | hofn
# Processing Record 10 of Set 2 | bolshoye kozino
# City not found. Skipping...
# Processing Record 11 of Set 2 | pueblo nuevo vinas
# Processing Record 12 of Set 2 | riyadh
# Processing Record 13 of Set 2 | sept-iles
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | chimore
# Processing Record 17 of Set 2 | faya
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | pacific grove
# Processing Record 20 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | sechura
# Processing Record 23 of Set 2 | morant bay
# Processing Record 24 of Set 2 | zyryanka
# Processing Record 25 of Set 2 | sambava
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | yar-sale
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | kaabong
# Processing Record 32 of Set 2 | kamen-na-obi
# Processing Record 33 of Set 2 | blonduos
# City not found. Skipping...
# Processing Record 34 of Set 2 | vila
# Processing Record 35 of Set 2 | cayenne
# Processing Record 36 of Set 2 | ust-omchug
# Processing Record 37 of Set 2 | ayr
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | rocha
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | bouloupari
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | nelson bay
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | petropavlovka
# Processing Record 49 of Set 2 | saldanha
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | beihai
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | augusto correa
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | doha
# Processing Record 7 of Set 3 | leh
# Processing Record 8 of Set 3 | jiayuguan
# Processing Record 9 of Set 3 | grand gaube
# Processing Record 10 of Set 3 | san carlos
# Processing Record 11 of Set 3 | kuala terengganu
# Processing Record 12 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 13 of Set 3 | nome
# Processing Record 14 of Set 3 | muisne
# Processing Record 15 of Set 3 | ancud
# Processing Record 16 of Set 3 | huangcun
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | igarka
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | floro
# Processing Record 24 of Set 3 | shingu
# Processing Record 25 of Set 3 | isla mujeres
# Processing Record 26 of Set 3 | khakhea
# Processing Record 27 of Set 3 | sao domingos
# Processing Record 28 of Set 3 | mehamn
# Processing Record 29 of Set 3 | lat yao
# Processing Record 30 of Set 3 | birao
# Processing Record 31 of Set 3 | mazatan
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | yenagoa
# Processing Record 34 of Set 3 | kenai
# Processing Record 35 of Set 3 | kaitangata
# Processing Record 36 of Set 3 | pauini
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | plettenberg bay
# Processing Record 39 of Set 3 | narsaq
# Processing Record 40 of Set 3 | samandag
# Processing Record 41 of Set 3 | atka
# City not found. Skipping...
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 44 of Set 3 | kumo
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | margate
# Processing Record 47 of Set 3 | terrace
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | carsamba
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | bonavista
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | luanda
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | usinsk
# Processing Record 7 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | mulatupo
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | zhangzhou
# Processing Record 12 of Set 4 | yamethin
# Processing Record 13 of Set 4 | jumla
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | mahina
# Processing Record 16 of Set 4 | ambulu
# Processing Record 17 of Set 4 | teguldet
# Processing Record 18 of Set 4 | mtambile
# Processing Record 19 of Set 4 | ixtapa
# Processing Record 20 of Set 4 | christchurch
# Processing Record 21 of Set 4 | pitimbu
# Processing Record 22 of Set 4 | paamiut
# Processing Record 23 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 4 | linxia
# Processing Record 25 of Set 4 | tuktoyaktuk
# Processing Record 26 of Set 4 | xichang
# Processing Record 27 of Set 4 | komsomolskiy
# Processing Record 28 of Set 4 | yumen
# Processing Record 29 of Set 4 | sorrento
# Processing Record 30 of Set 4 | olavarria
# Processing Record 31 of Set 4 | moiyabana
# City not found. Skipping...
# Processing Record 32 of Set 4 | kaeo
# Processing Record 33 of Set 4 | okhotsk
# Processing Record 34 of Set 4 | rio cuarto
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | bathsheba
# Processing Record 37 of Set 4 | clyde river
# Processing Record 38 of Set 4 | coihaique
# Processing Record 39 of Set 4 | gallipoli
# Processing Record 40 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 41 of Set 4 | praia
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 4 | rovinj
# Processing Record 45 of Set 4 | vila franca do campo
# Processing Record 46 of Set 4 | aksu
# Processing Record 47 of Set 4 | caravelas
# Processing Record 48 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 4 | lagoa
# Processing Record 50 of Set 4 | otavi
# Processing Record 1 of Set 5 | ipixuna
# Processing Record 2 of Set 5 | pangai
# Processing Record 3 of Set 5 | keti bandar
# Processing Record 4 of Set 5 | dakar
# Processing Record 5 of Set 5 | coos bay
# Processing Record 6 of Set 5 | geraldton
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | shizunai
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | ngunguru
# Processing Record 11 of Set 5 | bartica
# Processing Record 12 of Set 5 | kalmunai
# Processing Record 13 of Set 5 | axim
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | sinnamary
# Processing Record 18 of Set 5 | tateyama
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | adeje
# Processing Record 21 of Set 5 | ponta do sol
# Processing Record 22 of Set 5 | aylmer
# Processing Record 23 of Set 5 | segezha
# Processing Record 24 of Set 5 | bermejo
# Processing Record 25 of Set 5 | noumea
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | kourou
# Processing Record 28 of Set 5 | carbondale
# Processing Record 29 of Set 5 | otradnoye
# Processing Record 30 of Set 5 | mindelo
# Processing Record 31 of Set 5 | lorengau
# Processing Record 32 of Set 5 | tevaitoa
# Processing Record 33 of Set 5 | bandarbeyla
# Processing Record 34 of Set 5 | jibuti
# Processing Record 35 of Set 5 | santa rosa
# Processing Record 36 of Set 5 | banjar
# Processing Record 37 of Set 5 | dingle
# Processing Record 38 of Set 5 | mandan
# Processing Record 39 of Set 5 | kutum
# Processing Record 40 of Set 5 | rundu
# Processing Record 41 of Set 5 | henties bay
# Processing Record 42 of Set 5 | rosetown
# Processing Record 43 of Set 5 | husavik
# Processing Record 44 of Set 5 | havre-saint-pierre
# Processing Record 45 of Set 5 | la rioja
# Processing Record 46 of Set 5 | fomboni
# Processing Record 47 of Set 5 | souillac
# Processing Record 48 of Set 5 | zatoka
# Processing Record 49 of Set 5 | ocosingo
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 1 of Set 6 | forestville
# Processing Record 2 of Set 6 | vila velha
# Processing Record 3 of Set 6 | chicama
# Processing Record 4 of Set 6 | jiancheng
# Processing Record 5 of Set 6 | gornyy
# Processing Record 6 of Set 6 | borogontsy
# Processing Record 7 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 6 | mandalgovi
# Processing Record 9 of Set 6 | raglan
# Processing Record 10 of Set 6 | bogorodskoye
# Processing Record 11 of Set 6 | isangel
# Processing Record 12 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 13 of Set 6 | dalvik
# Processing Record 14 of Set 6 | egvekinot
# Processing Record 15 of Set 6 | artigas
# Processing Record 16 of Set 6 | dalian
# Processing Record 17 of Set 6 | bilma
# Processing Record 18 of Set 6 | moron
# Processing Record 19 of Set 6 | bambanglipuro
# Processing Record 20 of Set 6 | mandiana
# Processing Record 21 of Set 6 | arlit
# Processing Record 22 of Set 6 | castro
# Processing Record 23 of Set 6 | la asuncion
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 6 | tautira
# Processing Record 27 of Set 6 | soars
# Processing Record 28 of Set 6 | tual
# Processing Record 29 of Set 6 | benguela
# Processing Record 30 of Set 6 | chara
# Processing Record 31 of Set 6 | dingzhou
# Processing Record 32 of Set 6 | bure
# Processing Record 33 of Set 6 | valparaiso
# Processing Record 34 of Set 6 | yakshur-bodya
# City not found. Skipping...
# Processing Record 35 of Set 6 | kurumkan
# Processing Record 36 of Set 6 | nuuk
# Processing Record 37 of Set 6 | elverum
# Processing Record 38 of Set 6 | kieta
# Processing Record 39 of Set 6 | vidim
# Processing Record 40 of Set 6 | taonan
# Processing Record 41 of Set 6 | judaberg
# Processing Record 42 of Set 6 | pangnirtung
# Processing Record 43 of Set 6 | chumphon
# Processing Record 44 of Set 6 | ulaangom
# Processing Record 45 of Set 6 | hostotipaquillo
# Processing Record 46 of Set 6 | east wenatchee bench
# Processing Record 47 of Set 6 | mirina
# City not found. Skipping...
# Processing Record 48 of Set 6 | lompoc
# Processing Record 49 of Set 6 | san andres
# Processing Record 50 of Set 6 | batemans bay
# Processing Record 1 of Set 7 | saint-paul-les-dax
# Processing Record 2 of Set 7 | marsh harbour
# Processing Record 3 of Set 7 | mareeba
# Processing Record 4 of Set 7 | poltavka
# Processing Record 5 of Set 7 | tasiilaq
# Processing Record 6 of Set 7 | marawi
# Processing Record 7 of Set 7 | anito
# Processing Record 8 of Set 7 | sorland
# Processing Record 9 of Set 7 | krasnorechenskiy
# Processing Record 10 of Set 7 | bratsk
# Processing Record 11 of Set 7 | nouadhibou
# Processing Record 12 of Set 7 | mapiripan
# Processing Record 13 of Set 7 | taman
# Processing Record 14 of Set 7 | port-gentil
# Processing Record 15 of Set 7 | sayyan
# Processing Record 16 of Set 7 | banikoara
# Processing Record 17 of Set 7 | samfya
# Processing Record 18 of Set 7 | alofi
# Processing Record 19 of Set 7 | xiongzhou
# Processing Record 20 of Set 7 | davidson
# Processing Record 21 of Set 7 | bibiani
# Processing Record 22 of Set 7 | norman wells
# Processing Record 23 of Set 7 | laguna
# Processing Record 24 of Set 7 | sao joao da barra
# Processing Record 25 of Set 7 | moose jaw
# Processing Record 26 of Set 7 | karoi
# Processing Record 27 of Set 7 | pierre
# Processing Record 28 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 7 | cabo san lucas
# Processing Record 30 of Set 7 | bereda
# Processing Record 31 of Set 7 | kopidlno
# Processing Record 32 of Set 7 | saint-pierre
# Processing Record 33 of Set 7 | rawson
# Processing Record 34 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 7 | nyurba
# Processing Record 36 of Set 7 | altay
# Processing Record 37 of Set 7 | pemangkat
# Processing Record 38 of Set 7 | fairbanks
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | twin falls
# Processing Record 41 of Set 7 | half moon bay
# Processing Record 42 of Set 7 | emerald
# Processing Record 43 of Set 7 | kondoa
# Processing Record 44 of Set 7 | bonthe
# Processing Record 45 of Set 7 | slave lake
# Processing Record 46 of Set 7 | totma
# Processing Record 47 of Set 7 | valdivia
# Processing Record 48 of Set 7 | dicabisagan
# Processing Record 49 of Set 7 | upernavik
# Processing Record 50 of Set 7 | iqaluit
# Processing Record 1 of Set 8 | kodinsk
# Processing Record 2 of Set 8 | mogadouro
# Processing Record 3 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 4 of Set 8 | gogrial
# Processing Record 5 of Set 8 | teacapan
# Processing Record 6 of Set 8 | goderich
# Processing Record 7 of Set 8 | enniskerry
# Processing Record 8 of Set 8 | milkovo
# Processing Record 9 of Set 8 | smithers
# Processing Record 10 of Set 8 | flinders
# Processing Record 11 of Set 8 | manaus
# Processing Record 12 of Set 8 | el paso
# Processing Record 13 of Set 8 | tarakan
# Processing Record 14 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 8 | skjervoy
# Processing Record 16 of Set 8 | esil
# Processing Record 17 of Set 8 | skagen
# Processing Record 18 of Set 8 | howard springs
# Processing Record 19 of Set 8 | tiksi
# Processing Record 20 of Set 8 | disna
# Processing Record 21 of Set 8 | paragominas
# Processing Record 22 of Set 8 | sirfa
# City not found. Skipping...
# Processing Record 23 of Set 8 | weihe
# Processing Record 24 of Set 8 | ocos
# Processing Record 25 of Set 8 | hurghada
# Processing Record 26 of Set 8 | coahuayana
# Processing Record 27 of Set 8 | burica
# City not found. Skipping...
# Processing Record 28 of Set 8 | unai
# Processing Record 29 of Set 8 | gondanglegi
# Processing Record 30 of Set 8 | santa cruz
# Processing Record 31 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 8 | pingliang
# Processing Record 33 of Set 8 | necochea
# Processing Record 34 of Set 8 | kavieng
# Processing Record 35 of Set 8 | vostok
# Processing Record 36 of Set 8 | victoria
# Processing Record 37 of Set 8 | acarau
# Processing Record 38 of Set 8 | wuwei
# Processing Record 39 of Set 8 | srednekolymsk
# Processing Record 40 of Set 8 | semey
# Processing Record 41 of Set 8 | keningau
# Processing Record 42 of Set 8 | strezhevoy
# Processing Record 43 of Set 8 | gemena
# Processing Record 44 of Set 8 | sitka
# Processing Record 45 of Set 8 | codrington
# Processing Record 46 of Set 8 | tabriz
# Processing Record 47 of Set 8 | waiouru
# Processing Record 48 of Set 8 | varadero
# Processing Record 49 of Set 8 | hualmay
# Processing Record 50 of Set 8 | malakal
# Processing Record 1 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 9 | mandurah
# Processing Record 3 of Set 9 | teluk nibung
# Processing Record 4 of Set 9 | smolyaninovo
# Processing Record 5 of Set 9 | mackenzie
# Processing Record 6 of Set 9 | abu samrah
# Processing Record 7 of Set 9 | ginda
# Processing Record 8 of Set 9 | taungdwingyi
# Processing Record 9 of Set 9 | buala
# Processing Record 10 of Set 9 | kisesa
# Processing Record 11 of Set 9 | chiang klang
# Processing Record 12 of Set 9 | ust-nera
# Processing Record 13 of Set 9 | polikarpion
# City not found. Skipping...
# Processing Record 14 of Set 9 | tosya
# Processing Record 15 of Set 9 | sisimiut
# Processing Record 16 of Set 9 | mitsamiouli
# Processing Record 17 of Set 9 | maniitsoq
# Processing Record 18 of Set 9 | qasigiannguit
# Processing Record 19 of Set 9 | duverge
# Processing Record 20 of Set 9 | hastings
# Processing Record 21 of Set 9 | tilichiki
# Processing Record 22 of Set 9 | general roca
# Processing Record 23 of Set 9 | broome
# Processing Record 24 of Set 9 | avesta
# Processing Record 25 of Set 9 | jeremoabo
# Processing Record 26 of Set 9 | mingshui
# Processing Record 27 of Set 9 | kampong cham
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | knysna
# Processing Record 30 of Set 9 | dranceni sat
# City not found. Skipping...
# Processing Record 31 of Set 9 | hokitika
# Processing Record 32 of Set 9 | khash
# Processing Record 33 of Set 9 | belaya gora
# Processing Record 34 of Set 9 | wembley
# Processing Record 35 of Set 9 | maragogi
# Processing Record 36 of Set 9 | cururupu
# Processing Record 37 of Set 9 | jieshi
# Processing Record 38 of Set 9 | gangapur
# Processing Record 39 of Set 9 | senneterre
# Processing Record 40 of Set 9 | salym
# Processing Record 41 of Set 9 | aykhal
# Processing Record 42 of Set 9 | lufilufi
# Processing Record 43 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 44 of Set 9 | laem sing
# Processing Record 45 of Set 9 | camacha
# Processing Record 46 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 9 | ozinki
# Processing Record 48 of Set 9 | ouahigouya
# Processing Record 49 of Set 9 | shubarshi
# Processing Record 50 of Set 9 | stromness
# Processing Record 1 of Set 10 | japura
# Processing Record 2 of Set 10 | kiunga
# Processing Record 3 of Set 10 | aalestrup
# City not found. Skipping...
# Processing Record 4 of Set 10 | nisia floresta
# Processing Record 5 of Set 10 | safaga
# Processing Record 6 of Set 10 | tomatlan
# Processing Record 7 of Set 10 | balkhash
# Processing Record 8 of Set 10 | taltal
# Processing Record 9 of Set 10 | charlottesville
# Processing Record 10 of Set 10 | kruisfontein
# Processing Record 11 of Set 10 | takoradi
# Processing Record 12 of Set 10 | puerto baquerizo moreno
# Processing Record 13 of Set 10 | karratha
# Processing Record 14 of Set 10 | aklavik
# Processing Record 15 of Set 10 | gravelbourg
# Processing Record 16 of Set 10 | augustow
# Processing Record 17 of Set 10 | mount isa
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 10 | saint-francois
# Processing Record 21 of Set 10 | plouzane
# Processing Record 22 of Set 10 | itarema
# Processing Record 23 of Set 10 | amahai
# Processing Record 24 of Set 10 | palmer
# Processing Record 25 of Set 10 | bafoulabe
# Processing Record 26 of Set 10 | khartoum
# Processing Record 27 of Set 10 | hobyo
# Processing Record 28 of Set 10 | dauphin
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | kidal
# Processing Record 31 of Set 10 | florida
# Processing Record 32 of Set 10 | hvolsvollur
# Processing Record 33 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 10 | bodden town
# Processing Record 35 of Set 10 | damghan
# Processing Record 36 of Set 10 | kargasok
# Processing Record 37 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 10 | tiznit
# Processing Record 39 of Set 10 | buin
# Processing Record 40 of Set 10 | siyabuswa
# Processing Record 41 of Set 10 | meulaboh
# Processing Record 42 of Set 10 | kulhudhuffushi
# Processing Record 43 of Set 10 | tabas
# Processing Record 44 of Set 10 | emba
# Processing Record 45 of Set 10 | the valley
# Processing Record 46 of Set 10 | luderitz
# Processing Record 47 of Set 10 | opuwo
# Processing Record 48 of Set 10 | ust-kut
# Processing Record 49 of Set 10 | denpasar
# Processing Record 50 of Set 10 | quelimane
# Processing Record 1 of Set 11 | otjimbingwe
# Processing Record 2 of Set 11 | touros
# Processing Record 3 of Set 11 | daru
# Processing Record 4 of Set 11 | heinola
# Processing Record 5 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 11 | saint-augustin
# Processing Record 7 of Set 11 | mosquera
# Processing Record 8 of Set 11 | katherine
# Processing Record 9 of Set 11 | shirokiy
# Processing Record 10 of Set 11 | te anau
# Processing Record 11 of Set 11 | colon
# Processing Record 12 of Set 11 | bhabua
# Processing Record 13 of Set 11 | ambilobe
# Processing Record 14 of Set 11 | constitucion
# Processing Record 15 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 11 | korla
# Processing Record 17 of Set 11 | eucaliptus
# Processing Record 18 of Set 11 | mackay
# Processing Record 19 of Set 11 | bako
# Processing Record 20 of Set 11 | zandvoort
# Processing Record 21 of Set 11 | mage
# Processing Record 22 of Set 11 | albacete
# Processing Record 23 of Set 11 | beringovskiy
# Processing Record 24 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 11 | yulara
# Processing Record 26 of Set 11 | mogosani
# Processing Record 27 of Set 11 | najran
# Processing Record 28 of Set 11 | drayton valley
# Processing Record 29 of Set 11 | vayalar
# Processing Record 30 of Set 11 | svetlaya
# Processing Record 31 of Set 11 | liseleje
# Processing Record 32 of Set 11 | yashan
# Processing Record 33 of Set 11 | xam nua
# Processing Record 34 of Set 11 | elat
# Processing Record 35 of Set 11 | udachnyy
# Processing Record 36 of Set 11 | rolla
# Processing Record 37 of Set 11 | nioro
# Processing Record 38 of Set 11 | ucluelet
# Processing Record 39 of Set 11 | carbonia
# Processing Record 40 of Set 11 | huntington
# Processing Record 41 of Set 11 | matara
# Processing Record 42 of Set 11 | richards bay
# Processing Record 43 of Set 11 | los algarrobos
# Processing Record 44 of Set 11 | sur
# Processing Record 45 of Set 11 | erdenet
# Processing Record 46 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 11 | namibe
# Processing Record 48 of Set 11 | dandong
# Processing Record 49 of Set 11 | poum
# Processing Record 50 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 1 of Set 12 | torzhok
# Processing Record 2 of Set 12 | saint anthony
# Processing Record 3 of Set 12 | mahajanga
# Processing Record 4 of Set 12 | muroto
# Processing Record 5 of Set 12 | bajil
# Processing Record 6 of Set 12 | chumikan
# Processing Record 7 of Set 12 | rafai
# Processing Record 8 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 12 | porto santo
# Processing Record 10 of Set 12 | alekseyevsk
# Processing Record 11 of Set 12 | anchorage
# Processing Record 12 of Set 12 | prince rupert
# Processing Record 13 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 12 | asfi
# Processing Record 15 of Set 12 | haines junction
# Processing Record 16 of Set 12 | sungairaya
# Processing Record 17 of Set 12 | bayir
# Processing Record 18 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 12 | micheweni
# Processing Record 20 of Set 12 | aliwal north
# Processing Record 21 of Set 12 | maningrida
# Processing Record 22 of Set 12 | kayerkan
# Processing Record 23 of Set 12 | fort dodge
# Processing Record 24 of Set 12 | xining
# Processing Record 25 of Set 12 | kerman
# Processing Record 26 of Set 12 | north bend
# Processing Record 27 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 28 of Set 12 | kibala
# Processing Record 29 of Set 12 | san cristobal
# Processing Record 30 of Set 12 | rio gallegos
# Processing Record 31 of Set 12 | pontes e lacerda
# Processing Record 32 of Set 12 | berlevag
# Processing Record 33 of Set 12 | sabya
# Processing Record 34 of Set 12 | bjornevatn
# Processing Record 35 of Set 12 | muzhi
# Processing Record 36 of Set 12 | gat
# Processing Record 37 of Set 12 | tigil
# Processing Record 38 of Set 12 | saint-hyacinthe
# Processing Record 39 of Set 12 | dire dawa
# Processing Record 40 of Set 12 | tazmalt
# Processing Record 41 of Set 12 | tazovskiy
# Processing Record 42 of Set 12 | lafia
# Processing Record 43 of Set 12 | kiama
# Processing Record 44 of Set 12 | kavaratti
# Processing Record 45 of Set 12 | naze
# Processing Record 46 of Set 12 | zhuhai
# Processing Record 47 of Set 12 | sao gabriel da cachoeira
# Processing Record 48 of Set 12 | kununurra
# Processing Record 49 of Set 12 | andenes
# Processing Record 50 of Set 12 | bansi
# Processing Record 1 of Set 13 | smolenka
# Processing Record 2 of Set 13 | dudinka
# Processing Record 3 of Set 13 | kizukuri
# Processing Record 4 of Set 13 | vilhena
# Processing Record 5 of Set 13 | jardim
# Processing Record 6 of Set 13 | aleksandrovsk
# Processing Record 7 of Set 13 | rivera
# Processing Record 8 of Set 13 | lavrentiya
# Processing Record 9 of Set 13 | lyubech
# Processing Record 10 of Set 13 | vicksburg
# Processing Record 11 of Set 13 | naples
# Processing Record 12 of Set 13 | hasaki
# Processing Record 13 of Set 13 | tuatapere
# Processing Record 14 of Set 13 | harer
# Processing Record 15 of Set 13 | mafinga
# Processing Record 16 of Set 13 | majene
# Processing Record 17 of Set 13 | gizo
# Processing Record 18 of Set 13 | jijiga
# Processing Record 19 of Set 13 | kaspiyskiy
# Processing Record 20 of Set 13 | caceres
# Processing Record 21 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 22 of Set 13 | mazamari
# Processing Record 23 of Set 13 | lawrenceburg
# Processing Record 24 of Set 13 | carballo
# Processing Record 25 of Set 13 | tiarei
# Processing Record 26 of Set 13 | lac-megantic
# Processing Record 27 of Set 13 | waipawa
# Processing Record 28 of Set 13 | praia da vitoria
# Processing Record 29 of Set 13 | lebowakgomo
# Processing Record 30 of Set 13 | tura
# Processing Record 31 of Set 13 | port hedland
# Processing Record 32 of Set 13 | dubbo
# Processing Record 33 of Set 13 | kuala sungai baru
# Processing Record 34 of Set 13 | luganville
# Processing Record 35 of Set 13 | bilibino
# Processing Record 36 of Set 13 | san jose
# Processing Record 37 of Set 13 | umea
# Processing Record 38 of Set 13 | dire
# Processing Record 39 of Set 13 | mzimba
# Processing Record 40 of Set 13 | salalah
# Processing Record 41 of Set 13 | tynda
# Processing Record 42 of Set 13 | newport
# Processing Record 43 of Set 13 | paita
# Processing Record 44 of Set 13 | yarim
# Processing Record 45 of Set 13 | south venice
# Processing Record 46 of Set 13 | huarmey
# Processing Record 47 of Set 13 | wronki
# Processing Record 48 of Set 13 | gigmoto
# Processing Record 49 of Set 13 | bar harbor
# Processing Record 50 of Set 13 | tulsipur
# Processing Record 1 of Set 14 | aquidaba
# Processing Record 2 of Set 14 | urumqi
# Processing Record 3 of Set 14 | santa luzia
# Processing Record 4 of Set 14 | jalu
# Processing Record 5 of Set 14 | billings
# Processing Record 6 of Set 14 | kars
# Processing Record 7 of Set 14 | comodoro rivadavia
# Processing Record 8 of Set 14 | wazzan
# City not found. Skipping...
# Processing Record 9 of Set 14 | dunedin
# Processing Record 10 of Set 14 | lima
# Processing Record 11 of Set 14 | kenda
# Processing Record 12 of Set 14 | seguin
# Processing Record 13 of Set 14 | qaqortoq
# Processing Record 14 of Set 14 | wanaka
# Processing Record 15 of Set 14 | namatanai
# Processing Record 16 of Set 14 | cortez
# Processing Record 17 of Set 14 | breytovo
# Processing Record 18 of Set 14 | montepuez
# Processing Record 19 of Set 14 | faridan
# City not found. Skipping...
# Processing Record 20 of Set 14 | coari
# Processing Record 21 of Set 14 | kolvereid
# Processing Record 22 of Set 14 | araouane
# Processing Record 23 of Set 14 | kushiro
# Processing Record 24 of Set 14 | ossora
# Processing Record 25 of Set 14 | ust-kuyga
# Processing Record 26 of Set 14 | nikki
# Processing Record 27 of Set 14 | charlestown
# Processing Record 28 of Set 14 | kuybysheve
# Processing Record 29 of Set 14 | almas
# Processing Record 30 of Set 14 | mwembe
# Processing Record 31 of Set 14 | ca mau
# Processing Record 32 of Set 14 | marquette
# Processing Record 33 of Set 14 | svetlogorsk
# Processing Record 34 of Set 14 | anan
# Processing Record 35 of Set 14 | honningsvag
# Processing Record 36 of Set 14 | mahon
# Processing Record 37 of Set 14 | west bay
# Processing Record 38 of Set 14 | demirci
# Processing Record 39 of Set 14 | burns lake
# Processing Record 40 of Set 14 | roseburg
# Processing Record 41 of Set 14 | oranjestad
# Processing Record 42 of Set 14 | notodden
# Processing Record 43 of Set 14 | russell
# Processing Record 44 of Set 14 | salaverry
# Processing Record 45 of Set 14 | asyut
# Processing Record 46 of Set 14 | marzuq
# Processing Record 47 of Set 14 | atar
# Processing Record 48 of Set 14 | muros
# Processing Record 49 of Set 14 | walvis bay
# Processing Record 50 of Set 14 | ardakan
# Processing Record 1 of Set 15 | cockburn town
# Processing Record 2 of Set 15 | olyka
# Processing Record 3 of Set 15 | rio verde de mato grosso
# Processing Record 4 of Set 15 | challans
# Processing Record 5 of Set 15 | ketchikan
# Processing Record 6 of Set 15 | gravdal
# Processing Record 7 of Set 15 | hambantota
# Processing Record 8 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 15 | rohatyn
# Processing Record 10 of Set 15 | tacuati
# Processing Record 11 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 15 | hanko
# Processing Record 13 of Set 15 | krasnyy chikoy
# Processing Record 14 of Set 15 | palu
# Processing Record 15 of Set 15 | neiafu
# Processing Record 16 of Set 15 | lebedinyy
# Processing Record 17 of Set 15 | yei
# Processing Record 18 of Set 15 | clarksdale
# Processing Record 19 of Set 15 | melfi
# Processing Record 20 of Set 15 | fort nelson
# Processing Record 21 of Set 15 | vila do maio
# Processing Record 22 of Set 15 | londoko
# Processing Record 23 of Set 15 | curug
# Processing Record 24 of Set 15 | avera
# Processing Record 25 of Set 15 | esperance
# Processing Record 26 of Set 15 | vestmannaeyjar
# Processing Record 27 of Set 15 | zaragoza
# Processing Record 28 of Set 15 | mendi
# Processing Record 29 of Set 15 | cochrane
# Processing Record 30 of Set 15 | aloleng
# Processing Record 31 of Set 15 | ginir
# Processing Record 32 of Set 15 | benjamin hill
# Processing Record 33 of Set 15 | yarmouth
# Processing Record 34 of Set 15 | nhulunbuy
# Processing Record 35 of Set 15 | kielce
# Processing Record 36 of Set 15 | sarapul
# Processing Record 37 of Set 15 | misratah
# Processing Record 38 of Set 15 | kirkland lake
# Processing Record 39 of Set 15 | olinda
# Processing Record 40 of Set 15 | baculin
# Processing Record 41 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 15 | kapustin yar-1
# City not found. Skipping...
# Processing Record 43 of Set 15 | vung tau
# Processing Record 44 of Set 15 | kokopo
# Processing Record 45 of Set 15 | marienburg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Nemuro  43.3236  145.5750     53.69        68         100
# 1             Mataura -46.1927  168.8643     58.48        30           0
# 2               Enshi  30.3000  109.4833     65.14        77          98
# 3  Puerto Del Rosario  28.5004  -13.8627     71.35        73          75
# 4             Rikitea -23.1203 -134.9692     73.45        85         100
# 5              Atuona  -9.8000 -139.0333     77.47        73          45
# 6            Khatanga  71.9667  102.5000     -6.21        99         100
# 7              Torbay  47.6666  -52.7314     35.76        69         100
# 8                Chuy -33.6971  -53.4616     58.08        94          47
# 9          Chokurdakh  70.6333  147.9167     -8.70        99         100
#
#    Wind Speed Country Current Description
# 0       16.89      JP     overcast clouds
# 1        5.21      NZ           clear sky
# 2        0.36      CN     overcast clouds
# 3       16.11      ES       broken clouds
# 4        9.26      PF     overcast clouds
# 5       16.67      PF    scattered clouds
# 6        5.35      RU     overcast clouds
# 7       20.71      CA   light shower snow
# 8        6.69      UY    scattered clouds
# 9        8.68      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]



# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Nemuro      JP  43.3236  145.5750     53.69        68
# 1             Mataura      NZ -46.1927  168.8643     58.48        30
# 2               Enshi      CN  30.3000  109.4833     65.14        77
# 3  Puerto Del Rosario      ES  28.5004  -13.8627     71.35        73
# 4             Rikitea      PF -23.1203 -134.9692     73.45        85
#
#    Cloudiness  Wind Speed Current Description
# 0         100       16.89     overcast clouds
# 1           0        5.21           clear sky
# 2          98        0.36     overcast clouds
# 3          75       16.11       broken clouds
# 4         100        9.26     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
